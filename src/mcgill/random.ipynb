# %%
import pandas as pd

# %%
df_anthro = pd.read_csv("/Users/parth/mcgill-news-scraper/professors/arts/anthro_profs.csv")
df_anthro.head(10)
# Out:
#                  Name                  Department          Faculty
# 0         Diana Allan  Department of Anthropology  Faculty of Arts
# 1        Alyssa Bader  Department of Anthropology  Faculty of Arts
# 2       Samuele Collu  Department of Anthropology  Faculty of Arts
# 3      Nicole Couture  Department of Anthropology  Faculty of Arts
# 4         John Galaty  Department of Anthropology  Faculty of Arts
# 5  Sandra Teresa Hyde  Department of Anthropology  Faculty of Arts
# 6      Peter Johansen  Department of Anthropology  Faculty of Arts
# 7       Hillary Kaell  Department of Anthropology  Faculty of Arts
# 8        Eduardo Kohn  Department of Anthropology  Faculty of Arts
# 9    Katherine Lemons  Department of Anthropology  Faculty of Arts

# %%
df_res = pd.read_csv("/Users/parth/mcgill-news-scraper/professors/res.csv")
df_res.head(10)
# Out:
#                    Name                                         Department  \
# 0        Annmarie Adams        The Peter Guo-hua Fu School of Architecture
# 1         Marco Amabili               Department of Mechanical Engineering
# 2         Jorge Angeles               Department of Mechanical Engineering
# 3             Tal Arbel  Department of Electrical and Computer Engineering
# 4  Madhav Govind Badami                           School of Urban Planning
# 5        Bantwal Baliga               Department of Mechanical Engineering
# 6   Jeffrey Bergthorson               Department of Mechanical Engineering
# 7        Dimitrios Berk                 Department of Chemical Engineering
# 8         Kirk H. Bevan     Department of Mining and Materials Engineering
# 9    Matiyas A. Bezabeh                    Department of Civil Engineering
#
#                   Faculty
# 0  Faculty of Engineering
# 1  Faculty of Engineering
# 2  Faculty of Engineering
# 3  Faculty of Engineering
# 4  Faculty of Engineering
# 5  Faculty of Engineering
# 6  Faculty of Engineering
# 7  Faculty of Engineering
# 8  Faculty of Engineering
# 9  Faculty of Engineering

# %%
result = pd.concat([df_res, df_anthro])
result.tail
# Out:
# <bound method NDFrame.tail of                     Name                                         Department  \
# 0         Annmarie Adams        The Peter Guo-hua Fu School of Architecture
# 1          Marco Amabili               Department of Mechanical Engineering
# 2          Jorge Angeles               Department of Mechanical Engineering
# 3              Tal Arbel  Department of Electrical and Computer Engineering
# 4   Madhav Govind Badami                           School of Urban Planning
# ..                   ...                                                ...
# 22         Kathleen Rice                         Department of Anthropology
# 23         Sahar Sadjadi                         Department of Anthropology
# 24     Andre Costopoulos                         Department of Anthropology
# 25         Nadia Ferrara                         Department of Anthropology
# 26      Viviane Weitzner                         Department of Anthropology
#
#                    Faculty
# 0   Faculty of Engineering
# 1   Faculty of Engineering
# 2   Faculty of Engineering
# 3   Faculty of Engineering
# 4   Faculty of Engineering
# ..                     ...
# 22         Faculty of Arts
# 23         Faculty of Arts
# 24         Faculty of Arts
# 25         Faculty of Arts
# 26         Faculty of Arts
#
# [419 rows x 3 columns]>

# %%
result.to_csv("/Users/parth/mcgill-news-scraper/professors/new_res.csv",index=False)
